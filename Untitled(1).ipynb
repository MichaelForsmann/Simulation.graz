# %%
from datetime import datetime
import os
import numpy as np
import pandas as pd
from shapely import Point
import osmnx as ox 
import geopandas as gpd
from datetime import timedelta
import requests
import time
import dask_geopandas as dgpd
from matplotlib import cm
import dask.dataframe as dd

# %%
data=gpd.read_parquet("Data/Graz_total.gzip")

# %%
#Austria=gpd.read_parquet("Data/Austria_fullmap.gzip")
Austria_points=gpd.read_parquet("Data/Austria_fullmap_points.gzip")

# %%
Austria_points_par=Austria_points.reset_index()

# %%
Austria_points_par=dgpd.from_geopandas(Austria_points_par, npartitions=5)

# %%
start = time.time()
locatons=data.geometry.unique()
locatons1=gpd.GeoDataFrame(geometry=locatons.to_crs("EPSG:3035"),crs="EPSG:3035",index=data.station.unique())
X=gpd.sjoin(Austria_points,locatons1, predicate = 'dwithin',distance=50000).reset_index()
dataframe=[]
area=X["geometry"].area.groupby([X.index_right,X.osmid]).sum()
A=X.set_index(["index_right","osmid","feature"]).get_coordinates()
x,y=A.x,A.y
x0,y0=x.values-locatons1.loc[x.index.get_level_values("index_right")].geometry.x.values,y.values-locatons1.loc[y.index.get_level_values("index_right")].geometry.y.values
r=np.sqrt((x0)**2+(y0)**2)
theta=np.arctan2(x0,y0)
data_total=pd.DataFrame(np.array([r,theta]).T,columns=np.array(["r","theta"]),index=x.index)
for i in range(1000):
    scale=np.exp(-data_total.r.loc[data_total.index.get_level_values("index_right")==data.station.iloc[-1000+i]]/data.Windspeed.iloc[-1000+i]*0.0002)
    theta=np.abs(data_total.theta.loc[data_total.index.get_level_values("index_right")==data.station.iloc[-1000+i]]-data.angle.iloc[-1000+i])
    theta[theta>np.pi/2]=np.pi/2
    scale_theta=np.cos(theta)
    dat=pd.DataFrame({"scale_theta":scale_theta.values,"scale":scale.values},index=scale.index)
    scaled=(dat.scale*dat.scale_theta*area.loc[area.index.get_level_values("index_right")==data.station.iloc[-1000+i]])
    data1=scaled.groupby("feature").sum()
    dataframe.append(data1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[207], line 20
#      18 dat=pd.DataFrame({"scale_theta":scale_theta.values,"scale":scale.values},index=scale.index)
#      19 scaled=(dat.scale*dat.scale_theta*area.loc[area.index.get_level_values("index_right")==data.station.iloc[-1000+i]])
# ---> 20 data1=scaled.groupby("feature").sum()
#      21 dataframe.append(data1)
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:3146, in GroupBy.sum(self, numeric_only, min_count, engine, engine_kwargs)
#    3141 else:
#    3142     # If we are grouping on categoricals we want unobserved categories to
#    3143     # return zero, rather than the default of NaN which the reindexing in
#    3144     # _agg_general() returns. GH #31422
#    3145     with com.temp_setattr(self, "observed", True):
# -> 3146         result = self._agg_general(
#    3147             numeric_only=numeric_only,
#    3148             min_count=min_count,
#    3149             alias="sum",
#    3150             npfunc=np.sum,
#    3151         )
#    3153     return self._reindex_output(result, fill_value=0)
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1906, in GroupBy._agg_general(self, numeric_only, min_count, alias, npfunc, **kwargs)
#    1896 @final
#    1897 def _agg_general(
#    1898     self,
#    (...)
#    1904     **kwargs,
#    1905 ):
# -> 1906     result = self._cython_agg_general(
#    1907         how=alias,
#    1908         alt=npfunc,
#    1909         numeric_only=numeric_only,
#    1910         min_count=min_count,
#    1911         **kwargs,
#    1912     )
#    1913     return result.__finalize__(self.obj, method="groupby")
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1998, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1995     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996     return result
# -> 1998 new_mgr = data.grouped_reduce(array_func)
#    1999 res = self._wrap_agged_manager(new_mgr)
#    2000 if how in ["idxmin", "idxmax"]:
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/internals/base.py:367, in SingleDataManager.grouped_reduce(self, func)
#     365 def grouped_reduce(self, func):
#     366     arr = self.array
# --> 367     res = func(arr)
#     368     index = default_index(len(res))
#     370     mgr = type(self).from_array(res, index)
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1973, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1971 def array_func(values: ArrayLike) -> ArrayLike:
#    1972     try:
# -> 1973         result = self._grouper._cython_operation(
#    1974             "aggregate",
#    1975             values,
#    1976             how,
#    1977             axis=data.ndim - 1,
#    1978             min_count=min_count,
#    1979             **kwargs,
#    1980         )
#    1981     except NotImplementedError:
#    1982         # generally if we have numeric_only=False
#    1983         # and non-applicable functions
#    1984         # try to python agg
#    1985         # TODO: shouldn't min_count matter?
#    1986         # TODO: avoid special casing SparseArray here
#    1987         if how in ["any", "all"] and isinstance(values, SparseArray):
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/groupby/ops.py:831, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     829 ids, _, _ = self.group_info
#     830 ngroups = self.ngroups
# --> 831 return cy_op.cython_operation(
#     832     values=values,
#     833     axis=axis,
#     834     min_count=min_count,
#     835     comp_ids=ids,
#     836     ngroups=ngroups,
#     837     **kwargs,
#     838 )
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/groupby/ops.py:550, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     539 if not isinstance(values, np.ndarray):
#     540     # i.e. ExtensionArray
#     541     return values._groupby_op(
#     542         how=self.how,
#     543         has_dropped_na=self.has_dropped_na,
#    (...)
#     547         **kwargs,
#     548     )
# --> 550 return self._cython_op_ndim_compat(
#     551     values,
#     552     min_count=min_count,
#     553     ngroups=ngroups,
#     554     comp_ids=comp_ids,
#     555     mask=None,
#     556     **kwargs,
#     557 )
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/groupby/ops.py:329, in WrappedCythonOp._cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     327 if result_mask is not None:
#     328     result_mask = result_mask[None, :]
# --> 329 res = self._call_cython_op(
#     330     values2d,
#     331     min_count=min_count,
#     332     ngroups=ngroups,
#     333     comp_ids=comp_ids,
#     334     mask=mask,
#     335     result_mask=result_mask,
#     336     **kwargs,
#     337 )
#     338 if res.shape[0] == 1:
#     339     return res[0]
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/groupby/ops.py:418, in WrappedCythonOp._call_cython_op(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     407 counts = np.zeros(ngroups, dtype=np.int64)
#     408 if self.how in [
#     409     "idxmin",
#     410     "idxmax",
#    (...)
#     416     "sum",
#     417 ]:
# --> 418     func(
#     419         out=result,
#     420         counts=counts,
#     421         values=values,
#     422         labels=comp_ids,
#     423         min_count=min_count,
#     424         mask=mask,
#     425         result_mask=result_mask,
#     426         is_datetimelike=is_datetimelike,
#     427         **kwargs,
#     428     )
#     429 elif self.how in ["sem", "std", "var", "ohlc", "prod", "median"]:
#     430     if self.how in ["std", "sem"]:
#
# KeyboardInterrupt:

# %%
scale=np.exp(-data_total.r.loc[data_total.index.get_level_values("index_right")==data.station.iloc[i]]/data.Windspeed.iloc[i]*0.002)
theta=np.abs(data_total.theta.loc[data_total.index.get_level_values("index_right")==data.station.iloc[i]]-data.angle.iloc[i])

# %%
plt.plot(

# %%
import seaborn as sns

# %%
sns.heatmap(pd.DataFrame(dataframe).corr(),annot=True)

# %%
area_index.loc[area_index.index.get_level_values("index_right")==data.station.iloc[i]].index.get_level_values("feature")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 area_index.loc[area_index.index.get_level_values("index_right")==data.station.iloc[i]].index.get_level_values("feature")
#
# NameError: name 'area_index' is not defined

# %% [markdown]
# # Generating data for specific timepoints
# Scale the area of the sources with the distance, windspeed, and wind direction of the time point.
# We scale concentration with the average time from source to monitor $\frac{r_i}{V}=t$
# \begin{equation}
# r_{scale,k}(r,v_j,\lambda_p)=\sum_{i=1}^N exp(-\frac{\lambda_p r_i}{v_j})
# \end{equation}
# We also have a scaling term to take wind direction into account.
# \begin{equation}
# \theta_{scale,k}(\theta_i,\theta_{wind})=\sum_{i=1}^N cos(abs((\theta_i-\theta_{wind}))
# \end{equation}
# combining these two scaling functions and using the areas of the assumed sources as a proxy for the essmitionrate
# A_{source,k} instead of  dc/dt give us the final equation
# \begin{equation}
# A_{scale,k}=A_{source} \theta_{scale} r_{scale}
# \end{equation}
# for each monitor we than have the final amount of scaled area to be
# \begin{equation}
# A_{scale,f}=\sum_k A_{scale,f,k}
# \end{equation}

# %%
scale=np.exp(-data_total.r.loc[data_total.index.get_level_values("index_right")==data.station.iloc[0]]/data.Windspeed.iloc[0]*0.0002)
theta=np.abs(data_total.theta.loc[data_total.index.get_level_values("index_right")==data.station.iloc[0]]-data.angle.iloc[0])
theta[theta>np.pi/2]=np.pi/2
scale_theta=np.cos(theta)
dat=pd.DataFrame({"scale_theta":scale_theta.values,"scale":scale.values},index=scale.index)
scaled=(dat.scale*dat.scale_theta*area.loc[area.index.get_level_values("index_right")==data.station.iloc[0]])
data1=scaled.groupby("feature").sum()
dataframe.append(data1)

# %%
index123=(dat.scale*dat.scale_theta).loc[index[0]==dat.index.get_level_values("feature")]>0.01

# %%
plt.plot(data_total.r.loc[data_total.index.get_level_values("index_right")==data.station.iloc[k]],np.exp(-data_total.r.loc[data_total.index.get_level_values("index_right")==data.station.iloc[k]]/data.Windspeed.iloc[k]*0.0002))

# %%
k=100


scale=np.exp(-data_total.r.loc[data_total.index.get_level_values("index_right")==data.station.iloc[k]]/data.Windspeed.iloc[k]*0.0002)
theta=np.abs(data_total.theta.loc[data_total.index.get_level_values("index_right")==data.station.iloc[k]]-data.angle.iloc[k])
theta[theta>np.pi/2]=np.pi/2
scale_theta=np.cos(theta)
dat=pd.DataFrame({"scale_theta":scale_theta.values,"scale":scale.values},index=scale.index)
scaled=(dat.scale*dat.scale_theta*area.loc[area.index.get_level_values("index_right")==data.station.iloc[k]])
data1=scaled.groupby("feature").sum()
dataframe.append(data1)
import matplotlib.pyplot as plt
import numpy as np
#hest=['Pastel1', 'Pastel2', 'Paired', 'Accent', 'Dark2','Set1', 'Set2', 'Set3', 'tab10', 'tab20']
hest=['Greys', 'Purples', 'Blues', 'Greens', 'Oranges', 'Reds','YlOrBr', 'YlOrRd', 'OrRd','PuRd']
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'},figsize=(10,10))

for i in range(len(index)):
    top =plt.colormaps.get_cmap(hest[i])
    index123=(dat.scale*dat.scale_theta).loc[index[i]==dat.index.get_level_values("feature")]>0.01
    ax.scatter(data_total.loc[data_total.index.get_level_values("index_right")==data.station.iloc[k]].loc[index[i]==dat.index.get_level_values("feature")].theta.loc[index123],data_total.loc[data_total.index.get_level_values("index_right")==data.station.iloc[k]].loc[index[i]==dat.index.get_level_values("feature")].r.loc[index123],c=top((dat.scale*dat.scale_theta).loc[index[i]==dat.index.get_level_values("feature")].loc[index123]),s=0.01,label=index[i]+" "+hest[i])
arr1 = ax.arrow( data.angle.iloc[k],2000,np.pi,-1000, alpha = 1, width = 0.075,edgecolor = 'black', facecolor = 'Green')
ax.legend(labelcolor=["grey","purple","Blue","Green", "Orange","red","yellow"])
fig.savefig("newest_version.png")
